# %%
import matplotlib.pyplot as plt
from mapping import map_maker
import iris 

iris.FUTURE.netcdf_no_unlimited = True
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,6)

# %%
map_maker(data='data/example_vwind.nc', date_needed='2017-01-20', level=300,
          llat=20, llon=180, ulat=90, ulon=320, vmin=-60, vmax=60, colorbar=True)
plt.title('v-wind speed on 2017-01-20');
