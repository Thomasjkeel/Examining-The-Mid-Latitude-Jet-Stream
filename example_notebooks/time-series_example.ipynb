# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from timeseries import time_series_maker

plt.rcParams['figure.figsize'] =(12,6)

# %%
time_series_maker(vwnd_file='data/example_vwind.nc', uwnd_file='data/example_uwind.nc',
                  startdate='2017-01-01', enddate='2017-06-01', 
                  level=300, lon=220, lat=40, variable='mean v-wind (m/s)',
                  myWindow=12, running_mean=True)
